# %%
import timetocop
import matplotlib.pyplot as plt
import numpy as np
import os
import math
import scipy
import pandas as pd
from scipy import io
import statsmodels.api as sm
import statsmodels.formula.api as smf
import lifelines
from lifelines import*
from lifelines.statistics import multivariate_logrank_test

# %%
datapath = '/Volumes/LaCie/Projects/aDN_MB/behaviour/'

# %%
file_chrimson = 'aDN_Chrimson_Female_timtocop_lighton_.csv'
file_contr = 'otdChrimson_Female_timetocop_lighton.csv'
file_contr2 = 'aDN_stop_Chrimson_Female_timetocop_lighton.csv'

# %%
timetocop.kmf_plot(datapath, [file_chrimson, file_contr, file_contr2], 'kmfplot.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
#    test_statistic         p  -log2(p)
# 0        9.059095  0.010786  6.534756
